# %%
import pandas as pd
import numpy as np

# %%
data_met = pd.read_csv('final_met_data.csv')
data_rl = pd.read_csv('final_rl_data.csv')
data_distance = pd.read_csv('distance_relation_data.csv')
# Out:
# C:\Users\divya\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3331: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data_met = pd.merge(data_met, data_distance, on = 'station_no')

# %%
data_met.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1681846 entries, 0 to 1681845
# Data columns (total 13 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   datetime             1681846 non-null  object
#  1   station_no           1681846 non-null  object
#  2   temp                 1681846 non-null  float64
#  3   temp_max             1681846 non-null  float64
#  4   temp_min             1681846 non-null  float64
#  5   wind_dir             1681846 non-null  float64
#  6   wind_speed           1681846 non-null  float64
#  7   wind_dir_max         1681846 non-null  float64
#  8   wind_speed_max       1681846 non-null  float64
#  9   humidity             1681846 non-null  float64
#  10  precipitation        1681846 non-null  float64
#  11  precipitation_coeff  1681846 non-null  float64
#  12  site_id              1681846 non-null  object
# dtypes: float64(10), object(3)
# memory usage: 179.6+ MB

# %%
data_rl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1052756 entries, 0 to 1052755
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   datetime               1052756 non-null  object
#  1   type                   1052756 non-null  object
#  2   tip                    1052756 non-null  object
#  3   mlid                   1052756 non-null  object
#  4   mw_connection_no       1052756 non-null  object
#  5   site_id                1052756 non-null  object
#  6   card_type              1052756 non-null  object
#  7   adaptive_modulation    1052756 non-null  object
#  8   freq_band              1052756 non-null  object
#  9   severaly_error_second  1052756 non-null  float64
#  10  error_second           1052756 non-null  float64
#  11  unavail_second         1052756 non-null  float64
#  12  avail_time             1052756 non-null  float64
# ...

# %%
data = pd.merge(data_met, data_rl, on = ['datetime', 'site_id'])

# %%
data
# Out:
#           datetime station_no  temp  temp_max  temp_min  wind_dir  wind_speed  \
# 0       2018-12-31   WS_17062   9.7      10.2       9.4      16.0         4.9
# 1       2018-12-31   WS_17062   9.7      10.2       9.4      16.0         4.9
# 2       2018-12-31   WS_17062   9.7      10.2       9.4      16.0         4.9
# 3       2018-12-31   WS_17062   9.7      10.2       9.4      16.0         4.9
# 4       2018-12-31   WS_17062   9.7      10.2       9.4      16.0         4.9
# ...            ...        ...   ...       ...       ...       ...         ...
# 984714  2020-12-18   WS_19112   8.3       8.4       7.4       4.0         8.3
# 984715  2020-12-18   WS_19112   8.3       8.4       7.4       4.0         8.3
# 984716  2020-12-18   WS_19112   8.3       8.4       7.4       4.0         8.3
# 984717  2020-12-18   WS_19112   8.3       8.4       7.4       4.0         8.3
# 984718  2020-12-18   WS_19112   8.3       8.4       7.4       4.0         8.3
#
# ...

# %%
data.to_csv('data.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 984719 entries, 0 to 984718
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   datetime               984719 non-null  object
#  1   station_no             984719 non-null  object
#  2   temp                   984719 non-null  float64
#  3   temp_max               984719 non-null  float64
#  4   temp_min               984719 non-null  float64
#  5   wind_dir               984719 non-null  float64
#  6   wind_speed             984719 non-null  float64
#  7   wind_dir_max           984719 non-null  float64
#  8   wind_speed_max         984719 non-null  float64
#  9   humidity               984719 non-null  float64
#  10  precipitation          984719 non-null  float64
#  11  precipitation_coeff    984719 non-null  float64
#  12  site_id                984719 non-null  object
#  13  type                   984719 non-null  object
# ...
